# %%
student_database = {"A1234":"イトウ","K2355":"タナカ","U8922":"ヤマダ"}

student_number = input("学籍番号を入力してください")

name = student_database.get(student_number)

if name is not None:
  print(f"{name}さんの学籍番号ですね")
else:
  print("その学籍番号は登録されていません")
# Out:
# 学籍番号を入力してくださいU8922
# ヤマダさんの学籍番号ですね
